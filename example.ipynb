# %%
from fastai.vision.all import *
from AACN_Model import resnet50

# %%
CLASSES = 10

def prepare_data(img_size, batch_size):
    path = untar_data(URLs.IMAGENETTE_320)
    item_tfms=RandomResizedCrop(size=img_size, min_scale=0.8)
    batch_tfms=[*aug_transforms(flip_vert=False, max_lighting=0.2, max_rotate=15., max_zoom=1.1, max_warp=0.2, p_affine=0.75, p_lighting=0.75), 
                Normalize.from_stats(*imagenet_stats)]
    dls = ImageDataLoaders.from_folder(path, valid='val', item_tfms=item_tfms, batch_tfms=batch_tfms, bs=batch_size)  
    return dls

ds = prepare_data(224, 5)

# %%
ds.show_batch()

# %%
num_heads = 8
model = resnet50(num_classes=CLASSES, attention=[False,True,True,True], num_heads=num_heads)
learn = Learner(ds, model, opt_func=Adam, metrics=accuracy)

# %%
epochs = 1
lr = 1e-4
learn.fit(n_epoch=epochs, lr=lr, cbs=ReduceLROnPlateau(monitor='accuracy', min_delta=0.001, patience=10, factor=3, min_lr=1e-8))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='56' class='' max='1893' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       2.96% [56/1893 00:11<06:12 2.4625]
#     </div>
